# %%
! pip install panda

# %%
pandas
# Out:
# <module 'pandas' from 'C:\\Users\\gkora\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
import pandas

# %%
! pip install pandas

# %%
import pandas

# %%
data = pandas.read_csv("London_mobility.csv")

# %%
print(data)
# Out:
#       country_region_code  country_region    sub_region_1  \
# 0                      GB  United Kingdom  Greater London
# 1                      GB  United Kingdom  Greater London
# 2                      GB  United Kingdom  Greater London
# 3                      GB  United Kingdom  Greater London
# 4                      GB  United Kingdom  Greater London
# ...                   ...             ...             ...
# 29643                  GB  United Kingdom  Greater London
# 29644                  GB  United Kingdom  Greater London
# 29645                  GB  United Kingdom  Greater London
# 29646                  GB  United Kingdom  Greater London
# 29647                  GB  United Kingdom  Greater London
#
#                                 sub_region_2  metro_area iso_3166_2_code  \
# 0                                        NaN         NaN             NaN
# 1                                        NaN         NaN             NaN
# ...

# %%
data.describe()
# Out:
#        metro_area  census_fips_code  \
# count         0.0               0.0
# mean          NaN               NaN
# std           NaN               NaN
# min           NaN               NaN
# 25%           NaN               NaN
# 50%           NaN               NaN
# 75%           NaN               NaN
# max           NaN               NaN
#
#        retail_and_recreation_percent_change_from_baseline  \
# count                                       29630.000000
# mean                                          -35.198515
# std                                            24.474806
# min                                           -99.000000
# 25%                                           -53.000000
# 50%                                           -29.000000
# 75%                                           -16.000000
# max                                            90.000000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# ...

# %%
data_tuscany = pandas.read_csv("provinces_data.csv")

# %%
print(data_tuscany)
# Out:
#        Unnamed: 0   Location  day       date  total_number_positive_people  \
# 0               0         AR    0  24/2/2020                             0
# 1               1         FI    0  24/2/2020                             0
# 2               2         GR    0  24/2/2020                             0
# 3               3         LI    0  24/2/2020                             0
# 4               4         LU    0  24/2/2020                             0
# ...           ...        ...  ...        ...                           ...
# 10954       11796         PT  842  15/6/2022                         93378
# 10955       11797         SI  842  15/6/2022                         82487
# 10956       11799  aslCENTRO  842  15/6/2022                        497422
# 10957       11800      aslNO  842  15/6/2022                        418719
# 10958       11801      aslSE  842  15/6/2022                        251205
#
#        deaths  deaths_increase
# 0           0         0.000000
# ...

# %%
data_tuscany.describe()
# Out:
#          Unnamed: 0           day  total_number_positive_people        deaths  \
# count  10959.000000  10959.000000                  10959.000000  10959.000000
# mean    5900.230769    421.000000                  45104.442741    757.986313
# std     3407.099412    243.364071                  75885.899274    946.743112
# min        0.000000      0.000000                      0.000000      0.000000
# 25%     2950.000000    210.000000                   3316.000000    143.500000
# 50%     5900.000000    421.000000                  17846.000000    472.000000
# 75%     8850.500000    632.000000                  55322.000000    759.500000
# max    11801.000000    842.000000                 497422.000000   4936.000000
#
#        deaths_increase
# count     10959.000000
# mean          0.967533
# std           7.056762
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.377121
# max         300.000000
